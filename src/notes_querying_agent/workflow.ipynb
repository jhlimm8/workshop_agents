# %% [markdown]
# # Stage 1: Define the Problem Statement and Solve it Yourself

# %% [markdown]
# # Problem Statement: Sections in Lecture Notes are not equally informative. An effective way to find the most informative sections, is to filter the Notes for sections relevant to Tutorial Questions.
